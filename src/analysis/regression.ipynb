# %% [markdown]
# Goal: Find predictors of season length
# # Imports and setup

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
from scipy import stats
from tqdm import tqdm
import json
from pandas import json_normalize

#model zoo
from sklearn.linear_model import ElasticNet, BayesianRidge
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor as GradBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.gaussian_process import GaussianProcessRegressor as GPRegressor

#model selection
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

# %%
betas_path = r"../../data/processed/snow_betas.parquet"
stations_path = r"../../data/processed/stationswki.parquet"
path_season_length = r"../../data/processed/season_length.parquet"

betas_df = pd.read_parquet(betas_path)
stations_df = pd.read_parquet(stations_path)
season_length_df = pd.read_parquet(path_season_length)

# %%
stations_df.head()
# Out:
#                    name    region state_province  peak_elevation_ft  \
# 253  Mount Hood Skibowl  Cascades         Oregon             5027.0
# 254       Spout Springs  Cascades         Oregon             5450.0
# 252              Hoodoo  Cascades         Oregon             5703.0
# 251      Ferguson Ridge  Cascades         Oregon             5840.0
# 257       Warner Canyon  Cascades         Oregon             6003.0
#
#      base_elevation_ft  skiable_acreage  total_lifts  avg_annual_snowfall_in  \
# 253             3500.0            960.0          9.0                   300.0
# 254             4920.0            200.0          2.0                   130.0
# 252             4668.0            806.0          5.0                   360.0
# 251             5200.0            170.0          2.0                   300.0
# 257             5271.0            200.0          1.0                    50.0
#
#      avg_elevation_ft
# 253            4263.5
# 254            5185.0
# 252            5185.5
# 251            5520.0
# 257            5637.0

# %%
betas_df.tail()
# Out:
#                  station      beta         region
# Berkshire East      None  0.104517    New_England
# Showdown Montana    None -0.104772  Rockies_Other
# Terry Peak          None  0.003419          Other
# Timberline          None  0.130186           East
# Arapahoe Basin      None  0.118733       Colorado

# %%
betas_df = betas_df.drop(columns=["station", "region"]).rename_axis('station')
betas_df.head()
# Out:
#                    beta
# station
# Big Squaw     -0.206543
# Mt. Holiday   -0.692675
# Song Mountain  0.029599
# Blue Hills     0.589103
# Snowshoe       0.082373

# %%
season_length_df.head(6)
# Out:
#             station    region  length timestamp_start timestamp_end
# 0  49 Degrees North  Cascades     145      2010-11-16    2011-04-10
# 1  49 Degrees North  Cascades     143      2011-11-18    2012-04-09
# 2  49 Degrees North  Cascades     142      2012-11-19    2013-04-10
# 3  49 Degrees North  Cascades     145      2013-11-19    2014-04-13
# 4  49 Degrees North  Cascades     138      2014-11-14    2015-04-01
# 5  49 Degrees North  Cascades     125      2015-12-07    2016-04-10

# %%
season_length_avg_df = (season_length_df
                        .groupby(['station', 'region'])
                        [['length']]
                        .mean()
                        .reset_index()
                       )
season_length_avg_df.head()
# Out:
#             station    region      length
# 0  49 Degrees North  Cascades  138.666667
# 1        Afton Alps     Other  127.555556
# 2          Alpental  Cascades  154.444444
# 3     Alpine Valley     Other  114.555556
# 4              Alta      Utah  163.222222

# %%
complete_df = (pd.merge(left=stations_df, right=betas_df,
                        left_on="name", right_index=True)
               .merge(right=season_length_avg_df, left_on='name', right_on='station')
               .drop(columns=['region_y', 'total_lifts', 'state_province', 'name'])
               .rename(columns={'region_x': 'region', 'length': 'season_len'})
               .set_index('station')
               
                    )
complete_df.head()
# Out:
#                     region  peak_elevation_ft  base_elevation_ft  \
# station
# Spout Springs     Cascades             5450.0             4920.0
# Hoodoo            Cascades             5703.0             4668.0
# Willamette Pass   Cascades             6683.0             5120.0
# Timberline Lodge  Cascades             8540.0             4850.0
# Anthony Lakes     Cascades             8000.0             7100.0
#
#                   skiable_acreage  avg_annual_snowfall_in  avg_elevation_ft  \
# station
# Spout Springs               200.0                   130.0            5185.0
# Hoodoo                      806.0                   360.0            5185.5
# Willamette Pass             555.0                   430.0            5901.5
# Timberline Lodge           1430.0                   540.0            6695.0
# Anthony Lakes              1100.0                   300.0            7550.0
#
#                       beta  season_len
# station
# Spout Springs     0.185223   91.500000
# Hoodoo            0.817764  130.222222
# Willamette Pass   0.043802  124.125000
# Timberline Lodge  0.093837  246.428571
# Anthony Lakes     0.037908  127.000000

# %%
pd.get_dummies(data=complete_df, columns=['region'])
# Out:
#                       peak_elevation_ft  base_elevation_ft  skiable_acreage  \
# station
# Spout Springs                    5450.0             4920.0            200.0
# Hoodoo                           5703.0             4668.0            806.0
# Willamette Pass                  6683.0             5120.0            555.0
# Timberline Lodge                 8540.0             4850.0           1430.0
# Anthony Lakes                    8000.0             7100.0           1100.0
# 49 Degrees North                 5774.0             3923.0           2325.0
# Crystal Mountain                 7012.0             3912.0           2600.0
# White Pass                       6500.0             4500.0           1400.0
# Mission Ridge                    6820.0             4570.0           2000.0
# Sunlight Mountain                9895.0             7885.0            470.0
# Monarch                         11960.0            10790.0            800.0
# Arapahoe Basin                  13050.0            10520.0           1428.0
# Magic Mountain                   2850.0             1350.0            205.0
# Burke Mountain                   3267.0             1210.0            178.0
# Mad River Glen                   3637.0             1600.0            115.0
# Jay Peak                         3968.0             1815.0            385.0
# Pico Mountain                    3967.0             2000.0            468.0
# Soda Springs                     7325.0             6673.0            200.0
# Mountain High                    8200.0             6600.0            290.0
# Donner Ski Ranch                 7781.0             7031.0            435.0
# Northstar California             8610.0             6330.0           2904.0
# Bear Valley                      8500.0             6600.0           1280.0
# Snow Summit                      8174.0             6965.0            240.0
# Sugar Bowl                       8383.0             6883.0           1500.0
# China Peak                       8709.0             7030.0           1200.0
# Bear Mountain                    8805.0             7104.0            198.0
# Kirkwood                         9800.0             7800.0           2300.0
# June Mountain                   10090.0             7545.0            500.0
# Mammoth Mountain                11053.0             7953.0           3500.0
# Diamond Peak                     8540.0             6700.0            655.0
# Snowbasin                        9350.0             6391.0           3000.0
# Beaver Mountain                  8800.0             7200.0            667.0
# Deer Valley                      9570.0             6570.0           2026.0
# Powder Mountain                  9422.0             6900.0           8464.0
# Eagle Point                     10600.0             9100.0            650.0
# Brian Head                      11307.0             9600.0            650.0
#
#                       avg_annual_snowfall_in  avg_elevation_ft      beta  \
# station
# Spout Springs                          130.0            5185.0  0.185223
# Hoodoo                                 360.0            5185.5  0.817764
# Willamette Pass                        430.0            5901.5  0.043802
# Timberline Lodge                       540.0            6695.0  0.093837
# Anthony Lakes                          300.0            7550.0  0.037908
# 49 Degrees North                0               0            0
# Crystal Mountain                0               0            0
# White Pass                      0               0            0
# Mission Ridge                   0               0            0
# Sunlight Mountain               0               0            0
# Monarch                         0               0            0
# Arapahoe Basin                  0               0            0
# Magic Mountain                  1               0            0
# Burke Mountain                  1               0            0
# Mad River Glen                  1               0            0
# Jay Peak                        1               0            0
# Pico Mountain                   1               0            0
# Soda Springs                    0               1            0
# Mountain High                   0               1            0
# Donner Ski Ranch                0               1            0
# Northstar California            0               1            0
# Bear Valley                     0               1            0
# Snow Summit                     0               1            0
# Sugar Bowl                      0               1            0
# China Peak                      0               1            0
# Bear Mountain                   0               1            0
# Kirkwood                        0               1            0
# June Mountain                   0               1            0
# Mammoth Mountain                0               1            0
# Diamond Peak                    0               1            0
# Snowbasin                       0               0            1
# Beaver Mountain                 0               0            1
# Deer Valley                     0               0            1
# Powder Mountain                 0               0            1
# Eagle Point                     0               0            1
# Brian Head                      0               0            1

# %%
train, test = train_test_split(complete_df, test_size=.8)
def xy_split(data=None, ycol='season_len'):
    return data.copy().drop(columns=[ycol]), data.copy()[[ycol]]
X_train, y_train = xy_split(train)
X_test, y_test = xy_split(test)

# %%
X_test.head(20).to_numpy()

# %% [markdown]
# ## Regression
#
# ### Feature work

# %%
ProfileReport(stations_wbeta_df)

# %% [markdown]
# # Modeling

# %%
# Algos
linear = ElasticNet()
rforest = RandomForestRegressor()
gboost = GradBoostRegressor()
knn =  KNeighborsRegressor()
svm = SVR()
gp = GPRegressor()
models = ['linear', 'rforest', 'gboost', 'knn', 'svm', 'gp']

# %%
params = {}
params['linear'] = {'alpha': stats.uniform(.0001, 100),
                    'l1_ratio': stats.uniform(.1, .9)}
params['rforest'] = {'criterion': ('mse', 'mae'),
                     'max_features': ('log2', 'sqrt', .2, .15),  
                     'max_depth': (5, 15, 30),
                     'min_samples_split': (10, 20, 30)}
params['gboost'] = {'learning_rate': stats.uniform(.08, .12),
                    'n_estimators': (80, 100, 120)}
params['knn'] = {'n_neighbors': (3, 5, 7),
                 'weights': ('uniform', 'distance'),
                 'p': (1.5, 2, 2.5)}
params['svm'] = {'C': (.4, .7, 1, 1.3, 2, 10),
                 'epsilon': (.001, .01, .1), 
                 'kernel': ('linear', 'poly', 'rbf')}
params['gp'] = {'alpha': stats.uniform(1e-8, 1e-12)}

# %%
cv_scores_df = pd.DataFrame()#columns=['model', 'score'])
for model in tqdm(models):
    cv_object = RandomizedSearchCV(estimator=eval(model), 
                                   param_distributions=params[model], 
                                   n_iter=20, cv=5)
    scores = cross_validate(estimator=cv_object, scoring=['neg_mean_absolute_error', 'neg_mean_squared_error'],
                            X=X_train.to_numpy(), y=y_train.to_numpy(),
                            cv=5, n_jobs=-1, return_estimator=True)
    scores_df = pd.DataFrame(scores)   # todo: shorten
    cv_scores_df = pd.concat([cv_scores_df, scores_df], axis=0)

# %%
#json_normalize(scores_df)
scores_df

# %%
cv_scores_df.head(20)

# %%
for model in cv_scores:
    #print(json.loads(model))

# %%
cv_scores
